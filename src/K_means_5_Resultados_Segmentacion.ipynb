# %% [markdown]
# ## IMPORTS

# %%
import pandas as pd
import numpy as np
import utils
import matplotlib.pyplot as plt
from natsort import natsorted
import os

# %% [markdown]
# ## Mejores Segmentaciones tumorales

# %%
utils.plot_results_segmentation(type="K_Means", indices=[5,9,10,17])

# %% [markdown]
# ## Peores Segmentaciones tumorales

# %%
utils.plot_results_segmentation(type="K_Means", indices=[6,73,77,83])
