# %% [markdown]
# ## IMPORTS

# %%
import pandas as pd
import numpy as np
import utils
import matplotlib.pyplot as plt
from natsort import natsorted
import os

# %% [markdown]
# ## Mejores Segmentaciones tumorales

# %%
utils.plot_results_segmentation(type="DBScan", indices=[29,36,292,3]) #122 # 132

# %% [markdown]
# ## Peores Segmentaciones tumorales

# %%
utils.plot_results_segmentation(type="DBScan", indices=[240,93,290,280])
