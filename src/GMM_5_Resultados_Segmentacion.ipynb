# %% [markdown]
# ## IMPORTS

# %%
import pandas as pd
import numpy as np
import utils
import matplotlib.pyplot as plt
from natsort import natsorted
import os

# %% [markdown]
# ## Mejores Segmentaciones tumorales

# %%
utils.plot_results_segmentation(type="GMM", indices=[29,43,292,11])

# %% [markdown]
# ## Peores Segmentaciones tumorales

# %%
utils.plot_results_segmentation(type="GMM", indices=[1,44,290,280])
