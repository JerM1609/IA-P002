# %%
import pandas as pd
import numpy as np
import utils
import matplotlib.pyplot as plt
from natsort import natsorted
import os

# %% [markdown]
# ## Mejores Resultados de Similitud

# %%
X, image_names = utils.get_tumors_wavelet('Resultados/GMM/Matrices_Tumorales', iterations = 5)

# %%
utils.get_similar_tumors(X, image_names, index_to_test = 24, n_neighbors = 3)
utils.get_similar_tumors(X, image_names, index_to_test = 8, n_neighbors = 3)
utils.get_similar_tumors(X, image_names, index_to_test = 17, n_neighbors = 3)
utils.get_similar_tumors(X, image_names, index_to_test = 3, n_neighbors = 3)
utils.get_similar_tumors(X, image_names, index_to_test = 67, n_neighbors = 3)

# %% [markdown]
# ## Peores Resultados de Similitud

# %%
X, image_names = utils.get_tumors_wavelet('Resultados/K_Means/Matrices_Tumorales', iterations = 5)

# %%
utils.get_similar_tumors(X, image_names, index_to_test = 201, n_neighbors = 3)
utils.get_similar_tumors(X, image_names, index_to_test = 202, n_neighbors = 3)
utils.get_similar_tumors(X, image_names, index_to_test = 213, n_neighbors = 3)
utils.get_similar_tumors(X, image_names, index_to_test = 0, n_neighbors = 3)
utils.get_similar_tumors(X, image_names, index_to_test = 1, n_neighbors = 3)
