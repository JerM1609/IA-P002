# %%
import pandas as pd
import numpy as np
import utils
import matplotlib.pyplot as plt
from natsort import natsorted
import os

# %% [markdown]
# ## Mejores Resultados de Similitud

# %%
X, image_names = utils.get_tumors_wavelet('Resultados/DBScan/Matrices_Tumorales', iterations = 5)

# %%
utils.get_similar_tumors(X, image_names, index_to_test = 80, n_neighbors = 3)
utils.get_similar_tumors(X, image_names, index_to_test = 25, n_neighbors = 3)
utils.get_similar_tumors(X, image_names, index_to_test = 61, n_neighbors = 3)
utils.get_similar_tumors(X, image_names, index_to_test = 31, n_neighbors = 3)
utils.get_similar_tumors(X, image_names, index_to_test = 50, n_neighbors = 3)

# %% [markdown]
# ## Peores Resultados de Similitud

# %%
X, image_names = utils.get_tumors_wavelet('Resultados/DBScan/Matrices_Tumorales', iterations = 5)

# %%
utils.get_similar_tumors(X, image_names, index_to_test = 280, n_neighbors = 3)
utils.get_similar_tumors(X, image_names, index_to_test = 20, n_neighbors = 3)
utils.get_similar_tumors(X, image_names, index_to_test = 35, n_neighbors = 3)
utils.get_similar_tumors(X, image_names, index_to_test = 1, n_neighbors = 3)
utils.get_similar_tumors(X, image_names, index_to_test = 3, n_neighbors = 3)
